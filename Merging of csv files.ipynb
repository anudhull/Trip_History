# %%
import pandas as pd
from glob import glob

# %%
df_final = sorted(glob('mini project 2/*-capitalbikeshare-tripdata.csv'))
df_final
# Out:
# ['mini project 2\\2010-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2011-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2012Q1-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2012Q2-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2012Q3-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2012Q4-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2013Q1-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2013Q2-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2013Q3-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2013Q4-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2014Q1-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2014Q2-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2014Q3-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2014Q4-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2015Q1-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2015Q2-capitalbikeshare-tripdata.csv',
#  'mini project 2\\2015Q3-capitalbikeshare-tripdata.csv',
# ...

# %%
alldata = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in df_final),ignore_index=True)
alldata.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56                 31208
# 1        61  2010-09-20 11:41:22  2010-09-20 11:42:23                 31209
# 2      2690  2010-09-20 12:05:37  2010-09-20 12:50:27                 31600
# 3      1406  2010-09-20 12:06:05  2010-09-20 12:29:32                 31600
# 4      1413  2010-09-20 12:10:43  2010-09-20 12:34:17                 31100
#
#                    Start station  End station number  \
# 0       M St & New Jersey Ave SE               31108
# 1                 1st & N St  SE               31209
# 2                  5th & K St NW               31100
# 3                  5th & K St NW               31602
# 4  19th St & Pennsylvania Ave NW               31201
#
#                      End station Bike number Member type  \
# 0                  4th & M St SW      W00742      Member
# 1                 1st & N St  SE      W00032      Member
# ...

# %%
alldata.to_csv('final.csv',index=None)

# %%
alldata.tail()
# Out:
#           Duration           Start date             End date  \
# 26087118      1279  2020-01-31 23:56:42  2020-02-01 00:18:02
# 26087119       561  2020-01-31 23:57:19  2020-02-01 00:06:40
# 26087120       360  2020-01-31 23:58:51  2020-02-01 00:04:51
# 26087121      1491  2020-01-31 23:59:15  2020-02-01 00:24:07
# 26087122       637  2020-01-31 23:59:35  2020-02-01 00:10:13
#
#           Start station number  \
# 26087118                 31324
# 26087119                 31204
# 26087120                 32048
# 26087121                 31505
# 26087122                 31251
#
#                                               Start station  \
# 26087118                        18th & New Hampshire Ave NW
# 26087119                                     20th & E St NW
# 26087120  Bethesda Metro / Wisconsin Ave & Old Georgetow...
# 26087121                             Eckington Pl & Q St NE
# 26087122                                     12th & L St NW
#
# ...

# %%
alldata.describe()
# Out:
#            Duration  Start station number  End station number
# count  2.608712e+07          2.608712e+07        2.608712e+07
# mean   1.097207e+03          3.131041e+04        3.131133e+04
# std    2.103767e+03          2.730979e+02        2.729658e+02
# min    6.000000e+01          0.000000e+00        0.000000e+00
# 25%    3.980000e+02          3.120200e+04        3.120400e+04
# 50%    6.770000e+02          3.124600e+04        3.124500e+04
# 75%    1.152000e+03          3.150000e+04        3.150000e+04
# max    8.639400e+04          3.260900e+04        3.260900e+04

# %%
alldata.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-899a428af865> in <module>
# ----> 1 alldata.size()
#
# TypeError: 'numpy.int32' object is not callable

# %%
import numpy as np

# %%
alldata.size
# Out:
# 260871230

# %%
(pd.notnull(alldata)).describe()
